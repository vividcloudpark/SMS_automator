# %%
import numpy as np
import pandas as pd

# %%
taxfile = pd.read_excel("tax_finder.xlsx")
taxfile.head()
# Out:
#    Business Partner  Tax Number               korea_name  \
# 0          27489443  4838100107  HEUNGJIN METAL CO.,LTD.
# 1          12593367   110813515               SBCK Corp.
# 2          12626373  1368107674   DONGIN ENTECH CO.,LTD.
# 3          12819723   120866245               WeMB Corp.
# 4          12693710  2018602089       LOTTE JTB CO.,LTD.
#
#                   Eng_name
# 0  HEUNGJIN METAL CO.,LTD.
# 1               SBCK Corp.
# 2   DONGIN ENTECH CO.,LTD.
# 3               WeMB Corp.
# 4                      NaN

# %%
json = taxfile[taxfile["Tax Number"] == f'1368107674'].reset_index().T.to_dict()

# %%
json
# Out:
# {0: {'Business Partner': 12626373,
#   'Eng_name': 'DONGIN ENTECH CO.,LTD.',
#   'Tax Number': '1368107674',
#   'index': 2,
#   'korea_name': 'DONGIN ENTECH CO.,LTD.'}}

# %%
# Out:
#                       Business Partner                             korea_name  \
# Tax Number
# 4838100107                    27489443                HEUNGJIN METAL CO.,LTD.
# 110813515                     12593367                             SBCK Corp.
# 1368107674                    12626373                 DONGIN ENTECH CO.,LTD.
# 120866245                     12819723                             WeMB Corp.
# 2018602089                    12693710                     LOTTE JTB CO.,LTD.
# 1298638970                    12840594                       EB CARD CO.,LTD.
# 1148134808                    12700911             Daebo Industrial. Co., Ltd
# 6108535244                    12817703                          SK Innovation
# 2158136171                    12626930                  Whanin Pharm Co.,Ltd.
# 1048633995                    12774911                                   jTBC
# 2148144547                    12759182             SPIRAX.SARCO.Korea.Co.,Ltd
# ...
